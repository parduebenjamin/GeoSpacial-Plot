# %%
import plotly.plotly as py
import plotly
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import plotly.figure_factory as ff
#init_notebook_mode(connected=True)
plotly.tools.set_credentials_file(username='blah', api_key='blah')
import pandas as pd
import numpy as np
print('setup')
cDf = pd.read_csv("C:\\Users\\filepath.csv")

FIPSA = [53001,
            53003,
            53005,
            53007,
            53009,
            53011,
            53013,
            53015,
            53017,
            53019,
            53021,
            53023,
            53025,
            53027,
            53029,
            53031,
            53033,
            53035,
            53037,
            53039,
            53041,
            53043,
            53045,
            53047,
            53049,
            53051,
            53053,
            53055,
            53057,
            53059,
            53061,
            53063,
            53065,
            53067,
            53069,
            53071,
            53073,
            53075,
            53077]

employeeValues = [5159.97,
                    3545.32,
                    51430.27,
                    25674.5,
                    14327.97,
                    92374.83,
                    1065.86,
                    22417.85,
                    9402.45,
                    673,
                    25359.83,
                    485.5,
                    30340.96,
                    13949.25,
                    10656.22,
                    5563.72,
                    778598.13,
                    40788.01,
                    11422.52,
                    4801.36,
                    16795.99,
                    1690.86,
                    7602.7,
                    12533.92,
                    4274.4,
                    1935.59,
                    170867.04,
                    5124.35,
                    35494.1,
                    1600.1,
                    153087.08,
                    133704.7,
                    5613.3,
                    116346.48,
                    597.81,
                    15385.68,
                    59269.84,
                    11678.7,
                    74725.83]

#cDf['FIPs'] = cDf['FIPs'].astype(int)
cDf['FIPs'] = cDf['FIPs'].apply(lambda x: str(x).zfill(5))

#for col in cDf.columns:
#    cDf[col] = cDf[col].astype(str)

scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
    [0.4, 'rgb(188,189,220)'],
    [0.6, 'rgb(158,154,200)'],
    [0.8, 'rgb(117,107,177)'],
    [1.0, 'rgb(84,39,143)']
]

#endpoints may need to be a list
endpoints = [0,
            10000,
            20000,
            30000,
            40000,
            50000,
            60000,
            70000,
            80000,
            90000,
            100000,
            700000,
            800000
            ]


colors = [
        'rgb(0,0,0)',
        'rgb(15,15,15)',
        'rgb(30,30,30)',
        'rgb(45,45,45)',
        'rgb(60,60,60)',
        'rgb(75,75,75)',
        'rgb(90,90,90)',
        'rgb(105,105,105)',
        'rgb(120,120,120)',
        'rgb(135,135,135)',
        'rgb(150,150,150)',
        'rgb(165,165,165)',
        'rgb(180,180,180)',
        'rgb(195,195,195)',
        'rgb(210,210,210)',
        'rgb(225,225,225)',
        'rgb(240,240,240)'
]

colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"
]

cDf['text'] = cDf['County'] + '<br>' + \
    'Block number/Census Tract ' + cDf['BlockNumber_CensusTract'].astype(str) + ' City ' + cDf['City'].astype(str) + '<br>' + \
    ' Street Address ' + cDf['StreetAddress'].astype(str) + '<br>' + \
    'Zip Code ' + cDf['ZipCode'].astype(str) + ' Grand Total ' + cDf['GrandTotal'].astype(str)

FIPS = cDf['FIPs']
endpts = list(np.linspace(1, 12, len(colorscale) - 1))

cFig = ff.create_choropleth(
    colorscale = colors,
#    autocolorscale = False,
#    locations = cDf['FIPs'],
    fips = FIPSA,
#    values = cDf['GrandTotal'].astype(float),
    values = employeeValues,
    show_state_data = False,
    binning_endpoints = endpoints,
    show_hover = True, centroid_marker = {'opacity': 0},
    asp = 2.9,
#    text = cDf['text'],
    legend_title = '# Employees',
    title = "Employee Density by County"
)

layout = go.Layout(
    title = go.layout.Title(
        text = 'Employee Density by State <br>(Hover for breakdown)'
    ),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)
print('plots defined')
#fig = go.Figure(data = cData, layout = layout)
#py.iplot(fig, filename = 'choropleth_county_map')
plot_url = py.iplot(figure_or_data = cFig, filename = 'choropleth_full_usa', layout = layout)
py.iplot(figure_or_data = cFig, filename = 'choropleth_full_usa', layout = layout)
#cDf.head()
#cDf.to_csv("C:\\Users\\u1189580\\Downloads\\LOC - from Chris\\LOC - State by GeoType-testText.csv")
# Out:
# setup
# plots defined
